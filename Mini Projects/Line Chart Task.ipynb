# %% [markdown]
# # Line Chart Task

# %%
import pandas as pd
unrate = pd.read_csv('unrate.csv')
unrate
# Out:
#            DATE  VALUE
# 0    1948-01-01    3.4
# 1    1948-02-01    3.8
# 2    1948-03-01    4.0
# 3    1948-04-01    3.9
# 4    1948-05-01    3.5
# ..          ...    ...
# 819  2016-04-01    5.0
# 820  2016-05-01    4.7
# 821  2016-06-01    4.9
# 822  2016-07-01    4.9
# 823  2016-08-01    4.9
#
# [824 rows x 2 columns]

# %%
unrate.head()
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5

# %%
unrate.tail(10)
# Out:
#            DATE  VALUE
# 814  2015-11-01    5.0
# 815  2015-12-01    5.0
# 816  2016-01-01    4.9
# 817  2016-02-01    4.9
# 818  2016-03-01    5.0
# 819  2016-04-01    5.0
# 820  2016-05-01    4.7
# 821  2016-06-01    4.9
# 822  2016-07-01    4.9
# 823  2016-08-01    4.9

# %%
unrate['DATEtime'] = pd.to_datetime(unrate['DATE'])
unrate
# Out:
#           DATE  VALUE   DATEtime
# 0   1948-01-01    3.4 1948-01-01
# 1   1948-02-01    3.8 1948-02-01
# 2   1948-03-01    4.0 1948-03-01
# 3   1948-04-01    3.9 1948-04-01
# 4   1948-05-01    3.5 1948-05-01
# ..         ...    ...        ...
# 819 2016-04-01    5.0 2016-04-01
# 820 2016-05-01    4.7 2016-05-01
# 821 2016-06-01    4.9 2016-06-01
# 822 2016-07-01    4.9 2016-07-01
# 823 2016-08-01    4.9 2016-08-01
#
# [824 rows x 3 columns]

# %%
twelve_values=unrate.head(12)
twelve_values
# Out:
#          DATE  VALUE   DATEtime
# 0  1948-01-01    3.4 1948-01-01
# 1  1948-02-01    3.8 1948-02-01
# 2  1948-03-01    4.0 1948-03-01
# 3  1948-04-01    3.9 1948-04-01
# 4  1948-05-01    3.5 1948-05-01
# 5  1948-06-01    3.6 1948-06-01
# 6  1948-07-01    3.6 1948-07-01
# 7  1948-08-01    3.9 1948-08-01
# 8  1948-09-01    3.8 1948-09-01
# 9  1948-10-01    3.7 1948-10-01
# 10 1948-11-01    3.8 1948-11-01
# 11 1948-12-01    4.0 1948-12-01

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
plt.show()

# %%
a = twelve_values['DATE']
b = twelve_values['VALUE']

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.lineplot(a,b)
plt.xticks(rotation=40)
plt.xlabel('Month')
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')
plt.show()
